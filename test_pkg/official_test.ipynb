# %% [raw]
# In the project, the majority of tasks will undergo script testing, with only a few being reviewed by the TA. Be aware that this testing material is not final and cannot cover all testing scenarios. If you are caught cheating during testing, the whole group will receive a score of 0 for the project.

# %% [raw]
# The script checks using the requests library in Python. Before testing, ensure that the server has three users with the usernames "client1", "client2", and "client3", and the passwords "123". In the upcoming tests, if the Authorization field is needed, use "client1" and "123" as both the username and password.

# %%
import requests

# %% [raw]
# The initial check is the head request, a fundamental job of the server is to respond to the request. Use the "headers" parameter for logging into the server. Disregard this parameter if the server lacks the login feature.

# %%
headers={"Authorization": "Basic Y2xpZW50MToxMjM="}
q=requests.head('http://localhost:8080/',headers=headers)
print(q)
# Out:
# <Response [200]>

# %% [raw]
# Test get request

# %%
headers={"Authorization": "Basic Y2xpZW50MToxMjM="}
q=requests.get('http://localhost:8080/',headers=headers)
print(q)
# Out:
# <Response [200]>

# %% [raw]
# Test post request

# %%
headers={"Authorization": "Basic Y2xpZW50MToxMjM="}
q=requests.post('http://localhost:8080/',headers=headers)
print(q)
# Out:
# <Response [200]>

# %% [raw]
# Next, we will provide test examples based on the chapters in the project documentation. Each test is accompanied by a output. We do not check exact string matches for your output, as long as you complete the corresponding task.

# %%
#1.1
headers={"Authorization": "Basic Y2xpZW50MToxMjM="}
session = requests.Session()
session.headers.update({'Connection': 'keep-alive'})

response1 = session.get('http://127.0.0.1:8080',headers=headers)
response2 = session.get('http://127.0.0.1:8080',headers=headers)

print(response1)
print(response2)
# Out:
# <Response [200]>
# <Response [200]>

# %%
#1.2
#1.1
headers={"Authorization": "Basic Y2xpZW50MToxMjM="}
session1 = requests.Session()
session1.headers.update({'Connection': 'keep-alive'})
session2 = requests.Session()
session2.headers.update({'Connection': 'keep-alive'})

response1 = session1.get('http://127.0.0.1:8080',headers=headers)
response2 = session2.get('http://127.0.0.1:8080',headers=headers)


print(response1)
print(response2)
# Out:
# <Response [200]>
# <Response [200]>

# %%
#1.3
headers1={"Authorization": "Basic Y2xpZW50MToxMjM="}
headers2={}
q=requests.head('http://localhost:8080/',headers=headers1)
print(q)
q=requests.head('http://localhost:8080/',headers=headers2)
print(q)
# Out:
# <Response [200]>
# <Response [401]>

# %%
#2
url1='http://127.0.0.1:8080/?SUSTech-HTTP=1'

headers={"Authorization": "Basic Y2xpZW50MToxMjM="}
r=requests.get(url=url1, headers=headers)
print(r)
print(r.content.decode())
# Out:
# <Response [200]>
# ['11911922', '12589', 'a.py', 'a.txt', 'client1', 'client2', 'client3', 'favicon.ico']

# %%
#2
url2='http://127.0.0.1:8080/?SUSTech-HTTP=0'

headers={"Authorization": "Basic Y2xpZW50MToxMjM="}
r=requests.get(url=url2, headers=headers)
print(r.content.decode())
# Out:
# <!DOCTYPE html>
# <html lang='en'>
#
#     <head>
#         <title>File Server listening on ./data/</title>
#         <link href="https://cdn.jsdelivr.net/npm/daisyui@4.4.24/dist/full.min.css" rel="stylesheet" type="text/css" />
#         <script src="https://cdn.tailwindcss.com"></script>
#         <script src="https://cdn.jsdelivr.net/npm/axios@1.1.2/dist/axios.min.js"></script>
#         <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     </head>
#
#     <body class="h-screen bg-slate-100">
#         <div class="p-4 flex gap-4">
#
#             <div class="mockup-browser w-2/3 bg-base-100  border border-base-300 shadow-xl">
#                 <div class="mockup-browser-toolbar bg-base-100">
#                   <div class="input border border-base-300">./data/</div>
#                 </div>
#
#                 <div class="flex justify-center w-full px-8 py-8 border-t border-base-300">
#                     <div class="overflow-x-auto">
#                         <table class="table w-full">
#                           <!-- head -->
#                           <thead>
#                             <tr>
#                               <th></th>
#                               <th>Name</th>
#                               <th>Type</th>
#                               <th>Actions</th>
#                             </tr>
#                           </thead>
#                           <tbody>
#
#
#                             <!-- row 1 -->
#                             <tr>
#                               <th>1</th>
#                               <td>11911922</td>
#                               <td>Folder</td>
#                               <td>
#
#                                 <a class="btn btn-sm" href="http://localhost:8080/11911922?SUSTech-HTTP=0">
#                                   <img class="fill-current w-4 h-4" src="https://www.svgrepo.com/download/489457/enter.svg"></img>
#                                   <span>Enter Folder</span>
#                                 </a>
#
#                               </td>
#                             </tr>
#
#
#                             <!-- row 1 -->
#                             <tr>
#                               <th>2</th>
#                               <td>12589</td>
#                               <td>Folder</td>
#                               <td>
#
#                                 <a class="btn btn-sm" href="http://localhost:8080/12589?SUSTech-HTTP=0">
#                                   <img class="fill-current w-4 h-4" src="https://www.svgrepo.com/download/489457/enter.svg"></img>
#                                   <span>Enter Folder</span>
#                                 </a>
#
#                               </td>
#                             </tr>
#
#
#                             <!-- row 1 -->
#                             <tr>
#                               <th>3</th>
#                               <td>a.py</td>
#                               <td>File</td>
#                               <td>
#
#                                 <a class="btn btn-sm" href="http://localhost:8080/a.py?SUSTech-HTTP=0">
#                                     <img class="fill-current w-4 h-4" src="https://www.svgrepo.com/download/533682/download.svg"></img>
#                                     <span>Download</span>
#                                 </a>
#
#
#                               </td>
#                             </tr>
#
#
#                             <!-- row 1 -->
#                             <tr>
#                               <th>4</th>
#                               <td>a.txt</td>
#                               <td>File</td>
#                               <td>
#
#                                 <a class="btn btn-sm" href="http://localhost:8080/a.txt?SUSTech-HTTP=0">
#                                     <img class="fill-current w-4 h-4" src="https://www.svgrepo.com/download/533682/download.svg"></img>
#                                     <span>Download</span>
#                                 </a>
#
#
#                               </td>
#                             </tr>
#
#
#                             <!-- row 1 -->
#                             <tr>
#                               <th>5</th>
#                               <td>client1</td>
#                               <td>Folder</td>
#                               <td>
#
#                                 <a class="btn btn-sm" href="http://localhost:8080/client1?SUSTech-HTTP=0">
#                                   <img class="fill-current w-4 h-4" src="https://www.svgrepo.com/download/489457/enter.svg"></img>
#                                   <span>Enter Folder</span>
#                                 </a>
#
#                               </td>
#                             </tr>
#
#
#                             <!-- row 1 -->
#                             <tr>
#                               <th>6</th>
#                               <td>client2</td>
#                               <td>Folder</td>
#                               <td>
#
#                                 <a class="btn btn-sm" href="http://localhost:8080/client2?SUSTech-HTTP=0">
#                                   <img class="fill-current w-4 h-4" src="https://www.svgrepo.com/download/489457/enter.svg"></img>
#                                   <span>Enter Folder</span>
#                                 </a>
#
#                               </td>
#                             </tr>
#
#
#                             <!-- row 1 -->
#                             <tr>
#                               <th>7</th>
#                               <td>client3</td>
#                               <td>Folder</td>
#                               <td>
#
#                                 <a class="btn btn-sm" href="http://localhost:8080/client3?SUSTech-HTTP=0">
#                                   <img class="fill-current w-4 h-4" src="https://www.svgrepo.com/download/489457/enter.svg"></img>
#                                   <span>Enter Folder</span>
#                                 </a>
#
#                               </td>
#                             </tr>
#
#
#                             <!-- row 1 -->
#                             <tr>
#                               <th>8</th>
#                               <td>favicon.ico</td>
#                               <td>File</td>
#                               <td>
#
#                                 <a class="btn btn-sm" href="http://localhost:8080/favicon.ico?SUSTech-HTTP=0">
#                                     <img class="fill-current w-4 h-4" src="https://www.svgrepo.com/download/533682/download.svg"></img>
#                                     <span>Download</span>
#                                 </a>
#
#
#                               </td>
#                             </tr>
#
#                           </tbody>
#                         </table>
#                       </div>
#                 </div>
#
#                 <a class="absolute btn btn-sm bottom-2 right-2 btn btn-sm" href="http://localhost:8080/?SUSTech-HTTP=0" id="back">
#                   <img class="fill-current w-4 h-4" src="https://www.svgrepo.com/download/514186/out.svg"></img>
#                 </a>
#             </div>
#
#             <div class="w-1/3 flex flex-col gap-4">
#
#                 <div class="card w-96 bg-base-100 shadow-xl">
#                     <figure class="w-full h-48">
#                         <img src="https://upload.wikimedia.org/wikipedia/commons/c/cd/Night_of_SUSTech.jpg"
#                         alt="SUSTech-Night" />
#                     </figure>
#                     <div class="card-body">
#                         <h2 class="card-title">Welcome, client1</h2>
#                         <p>This is the file server project in SUSTech CS305. Hope you could have a good day!</p>
#                     </div>
#                 </div>
#
#
#             </div>
#         </div>
#
#
#     </body>
# </html>

# %%
#2
headers={"Authorization": "Basic Y2xpZW50MToxMjM="}
r=requests.get(url='http://127.0.0.1:8080/a.txt', headers=headers)
print(r.content.decode())
# Out:
# sadfsdfasdf

# %%
#3.1
files = {"firstFile": open('tmp/a.txt', "rb")}


data={}
headers={"Authorization": "Basic Y2xpZW50MToxMjM="}
r=requests.post(url='http://127.0.0.1:8080/upload?path=client1/',data=data,headers=headers, files=files)
print(r)
r=requests.post(url='http://127.0.0.1:8080/upload?path=client2/',data=data,headers=headers, files=files)
print(r)
# Out:
# <Response [200]>
# <Response [403]>

# %%
#3.2
url='http://127.0.0.1:8080/delete?path=client1/a.py'

headers={"Authorization": "Basic Y2xpZW50MToxMjM="}
r=requests.post(url=url, headers=headers)
print(r)
# Out:
# <Response [404]>

# %%
#4
url='http://127.0.0.1:8080/'

headers={"Authorization": "Basic Y2xpZW50MToxMjM="}
r=requests.get(url=url, headers=headers)
print(r.cookies.values()[0])
headers={"Cookie":'session-id='+r.cookies.values()[0]}
q=requests.get('http://localhost:8080/',headers=headers)
print(q)
# print(q.cookies)
# Out:
# LdiD3YmVgUXcXFpLNJG84g==
# {'Cookie': 'session-id=LdiD3YmVgUXcXFpLNJG84g=='}
# <Response [200]>

# %%
#5
headers={"Authorization": "Basic Y2xpZW50MToxMjM="}
r=requests.get(url='http://127.0.0.1:8080/client1/a.txt?chunked=1', headers=headers)
print(r)
# Out:
# <Response [200]>

# %%
#Breakpoint Transmission
url='http://127.0.0.1:8080/client1/a.txt'

data={}
headers={"Authorization": "Basic Y2xpZW50MToxMjM=",
         "Range": "0-1,1-2,2-3"}
r=requests.get(url=url, data=data, headers=headers)
print(r.content.decode())
# Out:
# --jtyd268pqik0124792apcp57fqzirzyt
# Content-Type: application/octet-stream
# Content-Range: bytes 0-1/11
#
# sa
# --jtyd268pqik0124792apcp57fqzirzyt
# Content-Type: application/octet-stream
# Content-Range: bytes 1-2/11
#
# ad
# --jtyd268pqik0124792apcp57fqzirzyt
# Content-Type: application/octet-stream
# Content-Range: bytes 2-3/11
#
# df
# --jtyd268pqik0124792apcp57fqzirzyt--
